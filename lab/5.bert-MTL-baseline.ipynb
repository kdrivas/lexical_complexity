# %%
from pathlib import Path
import pandas as pd
from torch.utils.data import DataLoader
import torch
from tqdm import tqdm
import numpy as np
import itertools
import random

from keras.preprocessing.sequence import pad_sequences

from transformers import BertTokenizer
from transformers import BertModel, AdamW, BertConfig
from transformers import get_linear_schedule_with_warmup
from transformers import DistilBertModel, AdamW
from transformers import BertForSequenceClassification

from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from pandarallel import pandarallel
pandarallel.initialize()

import os
os.chdir('..')

from src.data_lexical import LexDataset, read_lexical_corpus
from src.data_disambiguation import DisDataset, read_disambiguation_corpus
from src.model import BertForSharedTaskBaseline
from src.training import train, evaluate, forward_func_custom_bert
# Out:
# Using TensorFlow backend.
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
import math
import os
import warnings
from dataclasses import dataclass
from typing import Optional, Tuple

import torch
import torch.utils.checkpoint
from torch import nn
from torch.nn import CrossEntropyLoss, MSELoss
from transformers import BertPreTrainedModel, BertModel
from transformers.modeling_outputs import SequenceClassifierOutput


class BertForSharedTaskMultitask(BertPreTrainedModel):

    _keys_to_ignore_on_load_unexpected = [r"pooler"]

    def __init__(self, config):
        super().__init__(config)
        self.num_labels_first_task = 1 # Regression
        self.num_labels_second_task = config.num_labels # Word sense disambiguation

        self.bert = BertModel(config)
        self.dropout_first = nn.Dropout(config.hidden_dropout_prob)
        self.dropout_second = nn.Dropout(config.hidden_dropout_prob)
        
        self.classifier_first = nn.Linear(config.hidden_size, self.num_labels_first_task)
        self.classifier_second = nn.Linear(config.hidden_size, self.num_labels_second_task)

        self.init_weights()
        

    def forward(
        self,
        input_ids=None,
        target_positions=None,
        task_id=1,
        attention_mask=None,
        token_type_ids=None,
        position_ids=None,
        head_mask=None,
        inputs_embeds=None,
        labels=None,
        output_attentions=None,
        output_hidden_states=None,
        return_dict=None,
    ):
        r"""
        labels (:obj:`torch.LongTensor` of shape :obj:`(batch_size, sequence_length)`, `optional`):
            Labels for computing the token classification loss. Indices should be in ``[0, ..., config.num_labels -
            1]``.
        """
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        outputs = self.bert(
            input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            position_ids=position_ids,
            head_mask=head_mask,
            inputs_embeds=inputs_embeds,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
            return_dict=return_dict,
        )

        if task_id == 1:
            pooled_output = outputs[0][torch.arange(outputs[0].size(0)), target_positions]
            pooled_output = self.dropout_first(pooled_output)
            logits = self.classifier_first(pooled_output)

            loss = None
            if labels is not None:
                if self.num_labels_first_task == 1:
                    #  We are doing regression
                    loss_fct = MSELoss()
                    loss = loss_fct(logits.view(-1), labels.view(-1))
                else:
                    loss_fct = CrossEntropyLoss()
                    loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))

            if not return_dict:
                output = (logits,) + outputs[2:]
                return ((loss,) + output) if loss is not None else output

            return SequenceClassifierOutput(
                loss=loss,
                logits=logits,
                hidden_states=outputs.hidden_states,
                attentions=outputs.attentions,
            )
        elif task_id == 2:
            sequence_output = outputs[0]

            sequence_output = self.dropout_second(sequence_output)
            logits = self.classifier_second(sequence_output)

            loss = None
            if labels is not None:
                loss_fct = CrossEntropyLoss()
                # Only keep active parts of the loss
                if attention_mask is not None:
                    active_loss = attention_mask.view(-1) == 1
                    active_logits = logits.view(-1, self.num_labels_second_task)
                    active_labels = torch.where(
                        active_loss, labels.view(-1), torch.tensor(loss_fct.ignore_index).type_as(labels)
                    )
                    loss = loss_fct(active_logits, active_labels)
                else:
                    loss = loss_fct(logits.view(-1, self.num_labels_second_task), labels.view(-1))

            if not return_dict:
                output = (logits,) + outputs[2:]
                return ((loss,) + output) if loss is not None else output

            return TokenClassifierOutput(
                loss=loss,
                logits=logits,
                hidden_states=outputs.hidden_states,
                attentions=outputs.attentions,
            )

# %%
def forward_func_multitask_bert(batch, device, model, additional_params):

    # Clear gradients
    model.zero_grad()      
    b_input_ids = batch['input_ids'].to(device)
    b_input_mask = batch['attention_mask'].to(device)
        
    if additional_params['task_id'] == 1:
        b_labels = batch['labels'].to(device)
        b_positions =  batch['target_positions'].to(device)
      
        loss, logits = model(b_input_ids, 
                             b_positions,
                             task_id=1,
                             token_type_ids=None, 
                             attention_mask=b_input_mask, 
                             labels=b_labels)
    elif additional_params['task_id'] == 2:
        b_labels = batch['labels'].to(device)

        loss, logits = model(b_input_ids, 
                             task_id=2,
                             token_type_ids=None, 
                             attention_mask=b_input_mask, 
                             labels=b_labels)
    return loss, logits

# %%
epochs = 30
seed_val = 42
results_window = {}
max_len = 35

# %%
data_sent_dis, data_senses_dis = read_disambiguation_corpus(max_len=max_len)

tag_values = list(set(list(itertools.chain(*data_senses_dis))))
tag_values.append("PAD")
tag2idx = {t: i for i, t in enumerate(tag_values)}

# %%
# Load the BERT tokenizer.
print('Loading BERT tokenizer...')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
# Out:
# Loading BERT tokenizer...

# %%
train_encodings_dis = tokenizer(list(data_sent_dis), truncation=True, padding=True, max_length=max_len)

data_tags_dis = pad_sequences([[tag2idx.get(l) for l in lab] for lab in data_senses_dis],
                     maxlen=max_len, value=tag2idx["PAD"], padding="post",
                     dtype="long", truncating="post")
train_dataset_dis = DisDataset(train_encodings_dis, data_tags_dis)

train_loader_dis = DataLoader(train_dataset_dis, batch_size=32)

# %%
len(data_sent_dis)
# Out:
# 13210

# %%
import random
import numpy as np
from transformers import get_linear_schedule_with_warmup

for window_x in [0, 1, 2, 3]:
    with open(f'bert_mlt_baseline_{window_x}.txt', 'w') as f:
        f.write('running')
        
    print('Window size of ', window_x)
    data_texts, data_corpus, data_labels, sentence_raw, target_words, positions = read_lexical_corpus('data/raw/lcp_single_train.tsv',
                                                                           return_complete_sent=False,
                                                                           window_size=window_x + 1)
    torch.cuda.manual_seed_all(seed_val)

    kf = StratifiedKFold(8, shuffle=True, random_state=0)

    history_preds = []
    history_samples = []
    history_input = []
    history_target = []
    history_index = []
    history_labels = []
    history_occur_text = []
    history_occur_target = []
    ix_fold = 0

    for train_index, val_index in kf.split(data_texts, data_corpus):
        print('Starting a new fold ...')

        train_texts_lex, train_labels_lex, train_positions_lex, train_target_words_lex = data_texts[train_index], data_labels[train_index], positions[train_index], target_words[train_index]
        val_texts_lex, val_labels_lex, val_positions_lex, val_target_words_lex = data_texts[val_index], data_labels[val_index], positions[val_index], target_words[val_index]

        train_encodings_lex = tokenizer(list(train_texts_lex), truncation=True, padding=True)
        train_dataset_lex = LexDataset(train_encodings_lex, train_labels_lex, train_positions_lex)

        val_encodings_lex = tokenizer(list(val_texts_lex), truncation=True, padding=True)
        val_dataset_lex = LexDataset(val_encodings_lex, val_labels_lex, val_positions_lex)

        train_loader_lex = DataLoader(train_dataset_lex, batch_size=16)
        val_loader_lex = DataLoader(val_dataset_lex, batch_size=1)
        
        all_text = ' '.join(train_texts_lex)
        occurence_text = [all_text.count(w) for w in val_target_words_lex]
        
        occurence_target = [train_target_words_lex.tolist().count(w) for w in val_target_words_lex]
        
        device = torch.device("cuda:1")
        
        model = BertForSharedTaskMultitask.from_pretrained(
            "bert-base-uncased", 
            num_labels = len(tag2idx), 
            output_attentions = False, 
            output_hidden_states = False, 
        )
        model.cuda(1)
        device = torch.device("cuda:1")

        optimizer_lex = AdamW(model.parameters(),
                          lr = 2e-5, 
                          eps = 1e-8
                        )

        total_steps = len(train_loader_lex) * epochs
        scheduler_lex = get_linear_schedule_with_warmup(optimizer_lex, 
                                                    num_warmup_steps = 0, # Default value in run_glue.py
                                                    num_training_steps = total_steps)
        
        optimizer_dis = AdamW(model.parameters(),
                          lr = 2e-5, 
                          eps = 1e-8
                        )

        total_steps = len(train_loader_dis) * epochs
        scheduler_dis = get_linear_schedule_with_warmup(optimizer_dis, 
                                                    num_warmup_steps = 0, # Default value in run_glue.py
                                                    num_training_steps = total_steps)

        random.seed(seed_val)
        np.random.seed(seed_val)
        torch.manual_seed(seed_val)

        for epoch_i in range(0, epochs):
            print()
            print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
            train(device, model, train_loader_dis, forward_func_multitask_bert, optimizer_dis, scheduler_dis, {'task_id': 2})
            train(device, model, train_loader_lex, forward_func_multitask_bert, optimizer_lex, scheduler_lex, {'task_id': 1})
            
            training_stats, all_logits = evaluate(device, model, val_loader_lex, forward_func_multitask_bert, {'task_id': 1})

        history_labels.extend(val_labels_lex)
        history_preds.extend(all_logits)
        history_samples.extend(val_texts_lex)
        history_input.extend(sentence_raw[val_index])
        history_target.extend(target_words[val_index])
        history_index.extend(([ix_fold] * len(val_index)))
        history_occur_text.extend(occurence_text)
        history_occur_target.extend(occurence_target)
        ix_fold += 1

        print("")
        print("Training complete!")
        
        del model
        torch.cuda.empty_cache()
        
    results = pd.DataFrame()
    results['samples'] = history_samples
    results['preds'] = history_preds
    results['true_val'] = history_labels
    results['raw'] = history_input
    results['raw'] = results['raw'].astype(str)
    results['target'] = history_target
    results['index'] = history_index
    results['occur_text'] = history_occur_text
    results['occur_target'] = history_occur_target
    
    results_window[window_x] = results
# Out:
# Window size of  0
# Starting a new fold ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSharedTaskMultitask: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSharedTaskMultitask were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier_first.weight', 'classifier_first.bias', 'classifier_second.weight', 'classifier_second.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 30 ========
# Training...
#
#   Average training loss: 1.419985
# Training...
#
#   Average training loss: 0.023509
#
# Running Validation...
#   Metric: 0.271439
#   Validation Loss: 0.086788
#
# ======== Epoch 2 / 30 ========
# Training...
#
#   Average training loss: 1.022663
# Training...
#
#   Average training loss: 0.023181
#
# Running Validation...
#   Metric: 0.292394
#   Validation Loss: 0.099007
#
# ======== Epoch 3 / 30 ========
# Training...
#
#   Average training loss: 0.824133
# Training...
#
#   Average training loss: 0.020503
#
# Running Validation...
#   Metric: 0.270017
#   Validation Loss: 0.084750
#
# ======== Epoch 4 / 30 ========
# Training...
#
#   Average training loss: 0.776742
# Training...
#
#   Average training loss: 0.018324
#
# Running Validation...
#   Metric: 0.290717
#   Validation Loss: 0.097105
#
# ======== Epoch 5 / 30 ========
# Training...
#
#   Average training loss: 0.745644
# Training...
#
#   Average training loss: 0.017250
#
# Running Validation...
#   Metric: 0.275284
#   Validation Loss: 0.087190
#
# ======== Epoch 6 / 30 ========
# Training...
#
#   Average training loss: 0.723430
# Training...
#
#   Average training loss: 0.016382
#
# Running Validation...
#   Metric: 0.241480
#   Validation Loss: 0.068304
#
# ======== Epoch 7 / 30 ========
# Training...
#
#   Average training loss: 0.702430
# Training...
#
#   Average training loss: 0.018790
#
# Running Validation...
#   Metric: 0.241005
#   Validation Loss: 0.067476
#
# ======== Epoch 8 / 30 ========
# Training...
#
#   Average training loss: 0.679673
# Training...
#
#   Average training loss: 0.012723
#
# Running Validation...
#   Metric: 0.244268
#   Validation Loss: 0.069487
#
# ======== Epoch 9 / 30 ========
# Training...
#
#   Average training loss: 0.661152
# Training...
#
#   Average training loss: 0.013202
#
# Running Validation...
#   Metric: 0.228394
#   Validation Loss: 0.061442
#
# ======== Epoch 10 / 30 ========
# Training...
#
#   Average training loss: 0.638609
# Training...
#
#   Average training loss: 0.012034
#
# Running Validation...
#   Metric: 0.248564
#   Validation Loss: 0.071232
#
# ======== Epoch 11 / 30 ========
# Training...
#
#   Average training loss: 0.619675
# Training...
#
#   Average training loss: 0.013516
#
# Running Validation...
#   Metric: 0.231337
#   Validation Loss: 0.062456
#
# ======== Epoch 12 / 30 ========
# Training...
#
#   Average training loss: 0.599200
# Training...
#
#   Average training loss: 0.012551
#
# Running Validation...
#   Metric: 0.232875
#   Validation Loss: 0.063521
#
# ======== Epoch 13 / 30 ========
# Training...
#
#   Average training loss: 0.582712
# Training...
#
#   Average training loss: 0.012295
#
# Running Validation...
#   Metric: 0.225295
#   Validation Loss: 0.059646
#
# ======== Epoch 14 / 30 ========
# Training...
#
#   Average training loss: 0.559277
# Training...
#
#   Average training loss: 0.011713
#
# Running Validation...
#   Metric: 0.226122
#   Validation Loss: 0.059862
#
# ======== Epoch 15 / 30 ========
# Training...
#
#   Average training loss: 0.543308
# Training...
#
#   Average training loss: 0.012580
#
# Running Validation...
#   Metric: 0.214106
#   Validation Loss: 0.054150
#
# ======== Epoch 16 / 30 ========
# Training...
#
#   Average training loss: 0.522810
# Training...
#
#   Average training loss: 0.010997
#
# Running Validation...
#   Metric: 0.194099
#   Validation Loss: 0.045485
#
# ======== Epoch 17 / 30 ========
# Training...
#
#   Average training loss: 0.505083
# Training...
#
#   Average training loss: 0.012188
#
# Running Validation...
#   Metric: 0.179175
#   Validation Loss: 0.039347
#
# ======== Epoch 18 / 30 ========
# Training...
#
#   Average training loss: 0.490793
# Training...
#
#   Average training loss: 0.010490
#
# Running Validation...
#   Metric: 0.179402
#   Validation Loss: 0.039280
#
# ======== Epoch 19 / 30 ========
# Training...
#
#   Average training loss: 0.477065
# Training...
#
#   Average training loss: 0.008362
#
# Running Validation...
#   Metric: 0.169364
#   Validation Loss: 0.035387
#
# ======== Epoch 20 / 30 ========
# Training...
#
#   Average training loss: 0.464180
# Training...
#
#   Average training loss: 0.007105
#
# Running Validation...
#   Metric: 0.163960
#   Validation Loss: 0.033393
#
# ======== Epoch 21 / 30 ========
# Training...
#
#   Average training loss: 0.453811
# Training...
#
#   Average training loss: 0.007267
#
# Running Validation...
#   Metric: 0.138296
#   Validation Loss: 0.025007
#
# ======== Epoch 22 / 30 ========
# Training...
#
#   Average training loss: 0.445218
# Training...
#
#   Average training loss: 0.006956
#
# Running Validation...
#   Metric: 0.144942
#   Validation Loss: 0.027010
#
# ======== Epoch 23 / 30 ========
# Training...
#
#   Average training loss: 0.435264
# Training...
#
#   Average training loss: 0.006029
#
# Running Validation...
#   Metric: 0.122884
#   Validation Loss: 0.020259
#
# ======== Epoch 24 / 30 ========
# Training...
#
#   Average training loss: 0.426135
# Training...
#
#   Average training loss: 0.005353
#
# Running Validation...
#   Metric: 0.114380
#   Validation Loss: 0.017976
#
# ======== Epoch 25 / 30 ========
# Training...
#
#   Average training loss: 0.419538
# Training...
#
#   Average training loss: 0.005234
#
# Running Validation...
#   Metric: 0.094037
#   Validation Loss: 0.013013
#
# ======== Epoch 26 / 30 ========
# Training...
#
#   Average training loss: 0.413648
# Training...
#
#   Average training loss: 0.004932
#
# Running Validation...
#   Metric: 0.084770
#   Validation Loss: 0.011196
#
# ======== Epoch 27 / 30 ========
# Training...
#
#   Average training loss: 0.409000
# Training...
#
#   Average training loss: 0.004676
#
# Running Validation...
#   Metric: 0.077737
#   Validation Loss: 0.009755
#
# ======== Epoch 28 / 30 ========
# Training...
#
#   Average training loss: 0.406343
# Training...
#
#   Average training loss: 0.004433
#
# Running Validation...
#   Metric: 0.076458
#   Validation Loss: 0.009596
#
# ======== Epoch 29 / 30 ========
# Training...
#
#   Average training loss: 0.407795
# Training...
#
#   Average training loss: 0.004527
#
# Running Validation...
#   Metric: 0.074529
#   Validation Loss: 0.009250
#
# ======== Epoch 30 / 30 ========
# Training...
#
#   Average training loss: 0.410301
# Training...
#
#   Average training loss: 0.004373
#
# Running Validation...
#   Metric: 0.072850
#   Validation Loss: 0.008954
#
# Training complete!
# Starting a new fold ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSharedTaskMultitask: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSharedTaskMultitask were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier_first.weight', 'classifier_first.bias', 'classifier_second.weight', 'classifier_second.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 30 ========
# Training...
#
#   Average training loss: 1.434337
# Training...
#
#   Average training loss: 0.025467
#
# Running Validation...
#   Metric: 0.290443
#   Validation Loss: 0.097689
#
# ======== Epoch 2 / 30 ========
# Training...
#
#   Average training loss: 0.912552
# Training...
#
#   Average training loss: 0.020254
#
# Running Validation...
#   Metric: 0.290881
#   Validation Loss: 0.097835
#
# ======== Epoch 3 / 30 ========
# Training...
#
#   Average training loss: 0.824097
# Training...
#
#   Average training loss: 0.021465
#
# Running Validation...
#   Metric: 0.286719
#   Validation Loss: 0.094880
#
# ======== Epoch 4 / 30 ========
# Training...
#
#   Average training loss: 0.773329
# Training...
#
#   Average training loss: 0.019852
#
# Running Validation...
#   Metric: 0.256741
#   Validation Loss: 0.076757
#
# ======== Epoch 5 / 30 ========
# Training...
#
#   Average training loss: 0.741226
# Training...
#
#   Average training loss: 0.017517
#
# Running Validation...
#   Metric: 0.264439
#   Validation Loss: 0.080493
#
# ======== Epoch 6 / 30 ========
# Training...
#
#   Average training loss: 0.717354
# Training...
#
#   Average training loss: 0.014766
#
# Running Validation...
#   Metric: 0.274238
#   Validation Loss: 0.085326
#
# ======== Epoch 7 / 30 ========
# Training...
#
#   Average training loss: 0.697173
# Training...
#
#   Average training loss: 0.013958
#
# Running Validation...
#   Metric: 0.256716
#   Validation Loss: 0.075728
#
# ======== Epoch 8 / 30 ========
# Training...
#
#   Average training loss: 0.673619
# Training...
#
#   Average training loss: 0.014130
#
# Running Validation...
#   Metric: 0.270699
#   Validation Loss: 0.083007
#
# ======== Epoch 9 / 30 ========
# Training...
#
#   Average training loss: 0.655764
# Training...
#
#   Average training loss: 0.012998
#
# Running Validation...
#   Metric: 0.276962
#   Validation Loss: 0.086537
#
# ======== Epoch 10 / 30 ========
# Training...
#
#   Average training loss: 0.641611
# Training...
#
#   Average training loss: 0.013767
#
# Running Validation...
#   Metric: 0.236781
#   Validation Loss: 0.065245
#
# ======== Epoch 11 / 30 ========
# Training...
#
#   Average training loss: 0.624392
# Training...
#
#   Average training loss: 0.011368
#
# Running Validation...
#   Metric: 0.246523
#   Validation Loss: 0.070040
#
# ======== Epoch 12 / 30 ========
# Training...
#
#   Average training loss: 0.602874
# Training...
#
#   Average training loss: 0.011455
#
# Running Validation...
#   Metric: 0.223206
#   Validation Loss: 0.058523
#
# ======== Epoch 13 / 30 ========
# Training...
#
#   Average training loss: 0.587462
# Training...
#
#   Average training loss: 0.010602
#
# Running Validation...
#   Metric: 0.200890
#   Validation Loss: 0.048675
#
# ======== Epoch 14 / 30 ========
# Training...
#
#   Average training loss: 0.565131
# Training...
#
#   Average training loss: 0.008851
#
# Running Validation...
#   Metric: 0.209254
#   Validation Loss: 0.052327
#
# ======== Epoch 15 / 30 ========
# Training...
#
#   Average training loss: 0.548474
# Training...
#
#   Average training loss: 0.008911
#
# Running Validation...
#   Metric: 0.194789
#   Validation Loss: 0.046310
#
# ======== Epoch 16 / 30 ========
# Training...
#
#   Average training loss: 0.529857
# Training...
#
#   Average training loss: 0.009317
#
# Running Validation...
#   Metric: 0.186762
#   Validation Loss: 0.042841
#
# ======== Epoch 17 / 30 ========
# Training...
#
#   Average training loss: 0.515650
# Training...
#
#   Average training loss: 0.008959
#
# Running Validation...
#   Metric: 0.187494
#   Validation Loss: 0.042965
#
# ======== Epoch 18 / 30 ========
# Training...
#
#   Average training loss: 0.503275
# Training...
#
#   Average training loss: 0.008242
#
# Running Validation...
#   Metric: 0.179940
#   Validation Loss: 0.040036
#
# ======== Epoch 19 / 30 ========
# Training...
#
#   Average training loss: 0.492114
# Training...
#
#   Average training loss: 0.007571
#
# Running Validation...
#   Metric: 0.174997
#   Validation Loss: 0.038266
#
# ======== Epoch 20 / 30 ========
# Training...
#
#   Average training loss: 0.478669
# Training...
#
#   Average training loss: 0.007105
#
# Running Validation...
#   Metric: 0.152283
#   Validation Loss: 0.030035
#
# ======== Epoch 21 / 30 ========
# Training...
#
#   Average training loss: 0.466927
# Training...
#
#   Average training loss: 0.006352
#
# Running Validation...
#   Metric: 0.139532
#   Validation Loss: 0.026010
#
# ======== Epoch 22 / 30 ========
# Training...
#
#   Average training loss: 0.458298
# Training...
#
#   Average training loss: 0.005927
#
# Running Validation...
#   Metric: 0.130496
#   Validation Loss: 0.023305
#
# ======== Epoch 23 / 30 ========
# Training...
#
#   Average training loss: 0.450359
# Training...
#
#   Average training loss: 0.006423
#
# Running Validation...
#   Metric: 0.122045
#   Validation Loss: 0.020763
#
# ======== Epoch 24 / 30 ========
# Training...
#
#   Average training loss: 0.441950
# Training...
#
#   Average training loss: 0.006036
#
# Running Validation...
#   Metric: 0.100672
#   Validation Loss: 0.014622
#
# ======== Epoch 25 / 30 ========
# Training...
#
#   Average training loss: 0.434420
# Training...
#
#   Average training loss: 0.005556
#
# Running Validation...
#   Metric: 0.096330
#   Validation Loss: 0.013612
#
# ======== Epoch 26 / 30 ========
# Training...
#
#   Average training loss: 0.428323
# Training...
#
#   Average training loss: 0.005520
#
# Running Validation...
#   Metric: 0.090550
#   Validation Loss: 0.012266
#
# ======== Epoch 27 / 30 ========
# Training...
#
#   Average training loss: 0.424534
# Training...
#
#   Average training loss: 0.005368
#
# Running Validation...
#   Metric: 0.085434
#   Validation Loss: 0.011135
#
# ======== Epoch 28 / 30 ========
# Training...
#
#   Average training loss: 0.421369
# Training...
#
#   Average training loss: 0.005027
#
# Running Validation...
#   Metric: 0.083299
#   Validation Loss: 0.010873
#
# ======== Epoch 29 / 30 ========
# Training...
#
#   Average training loss: 0.421364
# Training...
#
#   Average training loss: 0.004726
#
# Running Validation...
#   Metric: 0.078827
#   Validation Loss: 0.009939
#
# ======== Epoch 30 / 30 ========
# Training...
#
#   Average training loss: 0.424182
# Training...
#
#   Average training loss: 0.004447
#
# Running Validation...
#   Metric: 0.075989
#   Validation Loss: 0.009301
#
# Training complete!
# Starting a new fold ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSharedTaskMultitask: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSharedTaskMultitask were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier_first.weight', 'classifier_first.bias', 'classifier_second.weight', 'classifier_second.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 30 ========
# Training...
#
#   Average training loss: 1.434337
# Training...
#
#   Average training loss: 0.023516
#
# Running Validation...
#   Metric: 0.350187
#   Validation Loss: 0.138201
#
# ======== Epoch 2 / 30 ========
# Training...
#
#   Average training loss: 0.910278
# Training...
#
#   Average training loss: 0.018864
#
# Running Validation...
#   Metric: 0.283383
#   Validation Loss: 0.094043
#
# ======== Epoch 3 / 30 ========
# Training...
#
#   Average training loss: 0.824681
# Training...
#
#   Average training loss: 0.018084
#
# Running Validation...
#   Metric: 0.274557
#   Validation Loss: 0.088308
#
# ======== Epoch 4 / 30 ========
# Training...
#
#   Average training loss: 0.773791
# Training...
#
#   Average training loss: 0.017025
#
# Running Validation...
#   Metric: 0.262023
#   Validation Loss: 0.080635
#
# ======== Epoch 5 / 30 ========
# Training...
#
#   Average training loss: 0.744035
# Training...
#
#   Average training loss: 0.017906
#
# Running Validation...
#   Metric: 0.273781
#   Validation Loss: 0.087507
#
# ======== Epoch 6 / 30 ========
# Training...
#
#   Average training loss: 0.715279
# Training...
#
#   Average training loss: 0.015107
#
# Running Validation...
#   Metric: 0.276734
#   Validation Loss: 0.088077
#
# ======== Epoch 7 / 30 ========
# Training...
#
#   Average training loss: 0.699253
# Training...
#
#   Average training loss: 0.013674
#
# Running Validation...
#   Metric: 0.250269
#   Validation Loss: 0.073354
#
# ======== Epoch 8 / 30 ========
# Training...
#
#   Average training loss: 0.678686
# Training...
#
#   Average training loss: 0.013593
#
# Running Validation...
#   Metric: 0.267784
#   Validation Loss: 0.082780
#
# ======== Epoch 9 / 30 ========
# Training...
#
#   Average training loss: 0.659166
# Training...
#
#   Average training loss: 0.012269
#
# Running Validation...
#   Metric: 0.269446
#   Validation Loss: 0.083420
#
# ======== Epoch 10 / 30 ========
# Training...
#
#   Average training loss: 0.642450
# Training...
#
#   Average training loss: 0.012108
#
# Running Validation...
#   Metric: 0.247241
#   Validation Loss: 0.071256
#
# ======== Epoch 11 / 30 ========
# Training...
#
#   Average training loss: 0.622577
# Training...
#
#   Average training loss: 0.013057
#
# Running Validation...
#   Metric: 0.229422
#   Validation Loss: 0.062303
#
# ======== Epoch 12 / 30 ========
# Training...
#
#   Average training loss: 0.602321
# Training...
#
#   Average training loss: 0.011087
#
# Running Validation...
#   Metric: 0.215327
#   Validation Loss: 0.055512
#
# ======== Epoch 13 / 30 ========
# Training...
#
#   Average training loss: 0.584446
# Training...
#
#   Average training loss: 0.012791
#
# Running Validation...
#   Metric: 0.188486
#   Validation Loss: 0.043886
#
# ======== Epoch 14 / 30 ========
# Training...
#
#   Average training loss: 0.562530
# Training...
#
#   Average training loss: 0.009609
#
# Running Validation...
#   Metric: 0.190811
#   Validation Loss: 0.044724
#
# ======== Epoch 15 / 30 ========
# Training...
#
#   Average training loss: 0.545632
# Training...
#
#   Average training loss: 0.008370
#
# Running Validation...
#   Metric: 0.195748
#   Validation Loss: 0.046684
#
# ======== Epoch 16 / 30 ========
# Training...
#
#   Average training loss: 0.526234
# Training...
#
#   Average training loss: 0.008160
#
# Running Validation...
#   Metric: 0.196922
#   Validation Loss: 0.047172
#
# ======== Epoch 17 / 30 ========
# Training...
#
#   Average training loss: 0.511978
# Training...
#
#   Average training loss: 0.007858
#
# Running Validation...
#   Metric: 0.179922
#   Validation Loss: 0.040249
#
# ======== Epoch 18 / 30 ========
# Training...
#
#   Average training loss: 0.501495
# Training...
#
#   Average training loss: 0.008332
#
# Running Validation...
#   Metric: 0.176550
#   Validation Loss: 0.038855
#
# ======== Epoch 19 / 30 ========
# Training...
#
#   Average training loss: 0.487757
# Training...
#
#   Average training loss: 0.007744
#
# Running Validation...
#   Metric: 0.188091
#   Validation Loss: 0.043504
#
# ======== Epoch 20 / 30 ========
# Training...
#
#   Average training loss: 0.474996
# Training...
#
#   Average training loss: 0.007587
#
# Running Validation...
#   Metric: 0.161770
#   Validation Loss: 0.033593
#
# ======== Epoch 21 / 30 ========
# Training...
#
#   Average training loss: 0.463083
# Training...
#
#   Average training loss: 0.007105
#
# Running Validation...
#   Metric: 0.142196
#   Validation Loss: 0.026805
#
# ======== Epoch 22 / 30 ========
# Training...
#
#   Average training loss: 0.453743
# Training...
#
#   Average training loss: 0.006079
#
# Running Validation...
#   Metric: 0.132120
#   Validation Loss: 0.023584
#
# ======== Epoch 23 / 30 ========
# Training...
#
#   Average training loss: 0.445316
# Training...
#
#   Average training loss: 0.005552
#
# Running Validation...
#   Metric: 0.119006
#   Validation Loss: 0.019647
#
# ======== Epoch 24 / 30 ========
# Training...
#
#   Average training loss: 0.437504
# Training...
#
#   Average training loss: 0.005219
#
# Running Validation...
#   Metric: 0.107176
#   Validation Loss: 0.016454
#
# ======== Epoch 25 / 30 ========
# Training...
#
#   Average training loss: 0.429981
# Training...
#
#   Average training loss: 0.005191
#
# Running Validation...
#   Metric: 0.097949
#   Validation Loss: 0.014227
#
# ======== Epoch 26 / 30 ========
# Training...
#
#   Average training loss: 0.423347
# Training...
#
#   Average training loss: 0.005054
#
# Running Validation...
#   Metric: 0.091888
#   Validation Loss: 0.012919
#
# ======== Epoch 27 / 30 ========
# Training...
#
#   Average training loss: 0.419302
# Training...
#
#   Average training loss: 0.005101
#
# Running Validation...
#   Metric: 0.082787
#   Validation Loss: 0.011075
#
# ======== Epoch 28 / 30 ========
# Training...
#
#   Average training loss: 0.415967
# Training...
#
#   Average training loss: 0.004805
#
# Running Validation...
#   Metric: 0.080690
#   Validation Loss: 0.010843
#
# ======== Epoch 29 / 30 ========
# Training...
#
#   Average training loss: 0.416592
# Training...
#
#   Average training loss: 0.004548
#
# Running Validation...
#   Metric: 0.078520
#   Validation Loss: 0.010402
#
# ======== Epoch 30 / 30 ========
# Training...
#
#   Average training loss: 0.419509
# Training...
#
#   Average training loss: 0.004274
#
# Running Validation...
#   Metric: 0.076447
#   Validation Loss: 0.009905
#
# Training complete!
# Starting a new fold ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSharedTaskMultitask: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSharedTaskMultitask were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier_first.weight', 'classifier_first.bias', 'classifier_second.weight', 'classifier_second.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 30 ========
# Training...
#
#   Average training loss: 1.434337
# Training...
#
#   Average training loss: 0.022735
#
# Running Validation...
#   Metric: 0.333147
#   Validation Loss: 0.125156
#
# ======== Epoch 2 / 30 ========
# Training...
#
#   Average training loss: 0.909928
# Training...
#
#   Average training loss: 0.020650
#
# Running Validation...
#   Metric: 0.264436
#   Validation Loss: 0.081611
#
# ======== Epoch 3 / 30 ========
# Training...
#
#   Average training loss: 0.825888
# Training...
#
#   Average training loss: 0.020787
#
# Running Validation...
#   Metric: 0.295494
#   Validation Loss: 0.099558
#
# ======== Epoch 4 / 30 ========
# Training...
#
#   Average training loss: 0.774914
# Training...
#
#   Average training loss: 0.018684
#
# Running Validation...
#   Metric: 0.245010
#   Validation Loss: 0.070190
#
# ======== Epoch 5 / 30 ========
# Training...
#
#   Average training loss: 0.744401
# Training...
#
#   Average training loss: 0.017532
#
# Running Validation...
#   Metric: 0.301898
#   Validation Loss: 0.102970
#
# ======== Epoch 6 / 30 ========
# Training...
#
#   Average training loss: 0.719696
# Training...
#
#   Average training loss: 0.016305
#
# Running Validation...
#   Metric: 0.299436
#   Validation Loss: 0.100092
#
# ======== Epoch 7 / 30 ========
# Training...
#
#   Average training loss: 0.701676
# Training...
#
#   Average training loss: 0.015556
#
# Running Validation...
#   Metric: 0.245728
#   Validation Loss: 0.069569
#
# ======== Epoch 8 / 30 ========
# Training...
#
#   Average training loss: 0.677659
# Training...
#
#   Average training loss: 0.014026
#
# Running Validation...
#   Metric: 0.272416
#   Validation Loss: 0.083472
#
# ======== Epoch 9 / 30 ========
# Training...
#
#   Average training loss: 0.658348
# Training...
#
#   Average training loss: 0.012641
#
# Running Validation...
#   Metric: 0.273194
#   Validation Loss: 0.084073
#
# ======== Epoch 10 / 30 ========
# Training...
#
#   Average training loss: 0.642915
# Training...
#
#   Average training loss: 0.015082
#
# Running Validation...
#   Metric: 0.243787
#   Validation Loss: 0.067946
#
# ======== Epoch 11 / 30 ========
# Training...
#
#   Average training loss: 0.627044
# Training...
#
#   Average training loss: 0.012799
#
# Running Validation...
#   Metric: 0.236757
#   Validation Loss: 0.064754
#
# ======== Epoch 12 / 30 ========
# Training...
#
#   Average training loss: 0.605962
# Training...
#
#   Average training loss: 0.013860
#
# Running Validation...
#   Metric: 0.232608
#   Validation Loss: 0.062778
#
# ======== Epoch 13 / 30 ========
# Training...
#
#   Average training loss: 0.589813
# Training...
#
#   Average training loss: 0.011572
#
# Running Validation...
#   Metric: 0.218964
#   Validation Loss: 0.056534
#
# ======== Epoch 14 / 30 ========
# Training...
#
#   Average training loss: 0.570369
# Training...
#
#   Average training loss: 0.010767
#
# Running Validation...
#   Metric: 0.206038
#   Validation Loss: 0.050026
#
# ======== Epoch 15 / 30 ========
# Training...
#
#   Average training loss: 0.551613
# Training...
#
#   Average training loss: 0.008213
#
# Running Validation...
#   Metric: 0.211523
#   Validation Loss: 0.052394
#
# ======== Epoch 16 / 30 ========
# Training...
#
#   Average training loss: 0.533392
# Training...
#
#   Average training loss: 0.010203
#
# Running Validation...
#   Metric: 0.200365
#   Validation Loss: 0.047569
#
# ======== Epoch 17 / 30 ========
# Training...
#
#   Average training loss: 0.519340
# Training...
#
#   Average training loss: 0.009378
#
# Running Validation...
#   Metric: 0.183100
#   Validation Loss: 0.040468
#
# ======== Epoch 18 / 30 ========
# Training...
#
#   Average training loss: 0.505306
# Training...
#
#   Average training loss: 0.008020
#
# Running Validation...
#   Metric: 0.171386
#   Validation Loss: 0.036193
#
# ======== Epoch 19 / 30 ========
# Training...
#
#   Average training loss: 0.493697
# Training...
#
#   Average training loss: 0.006641
#
# Running Validation...
#   Metric: 0.168085
#   Validation Loss: 0.035231
#
# ======== Epoch 20 / 30 ========
# Training...
#
#   Average training loss: 0.480104
# Training...
#
#   Average training loss: 0.007207
#
# Running Validation...
#   Metric: 0.156506
#   Validation Loss: 0.030940
#
# ======== Epoch 21 / 30 ========
# Training...
#
#   Average training loss: 0.469115
# Training...
#
#   Average training loss: 0.006615
#
# Running Validation...
#   Metric: 0.142503
#   Validation Loss: 0.026402
#
# ======== Epoch 22 / 30 ========
# Training...
#
#   Average training loss: 0.459736
# Training...
#
#   Average training loss: 0.005888
#
# Running Validation...
#   Metric: 0.130715
#   Validation Loss: 0.022812
#
# ======== Epoch 23 / 30 ========
# Training...
#
#   Average training loss: 0.450184
# Training...
#
#   Average training loss: 0.005637
#
# Running Validation...
#   Metric: 0.120341
#   Validation Loss: 0.019867
#
# ======== Epoch 24 / 30 ========
# Training...
#
#   Average training loss: 0.442197
# Training...
#
#   Average training loss: 0.005594
#
# Running Validation...
#   Metric: 0.107631
#   Validation Loss: 0.016596
#
# ======== Epoch 25 / 30 ========
# Training...
#
#   Average training loss: 0.434410
# Training...
#
#   Average training loss: 0.005425
#
# Running Validation...
#   Metric: 0.090251
#   Validation Loss: 0.012484
#
# ======== Epoch 26 / 30 ========
# Training...
#
#   Average training loss: 0.428112
# Training...
#
#   Average training loss: 0.005232
#
# Running Validation...
#   Metric: 0.089666
#   Validation Loss: 0.012502
#
# ======== Epoch 27 / 30 ========
# Training...
#
#   Average training loss: 0.424002
# Training...
#
#   Average training loss: 0.005079
#
# Running Validation...
#   Metric: 0.081768
#   Validation Loss: 0.010721
#
# ======== Epoch 28 / 30 ========
# Training...
#
#   Average training loss: 0.420832
# Training...
#
#   Average training loss: 0.004870
#
# Running Validation...
#   Metric: 0.079754
#   Validation Loss: 0.010384
#
# ======== Epoch 29 / 30 ========
# Training...
#
#   Average training loss: 0.420691
# Training...
#
#   Average training loss: 0.004760
#
# Running Validation...
#   Metric: 0.076869
#   Validation Loss: 0.009847
#
# ======== Epoch 30 / 30 ========
# Training...
#
#   Average training loss: 0.423648
# Training...
#
#   Average training loss: 0.004363
#
# Running Validation...
#   Metric: 0.072933
#   Validation Loss: 0.008991
#
# Training complete!
# Starting a new fold ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSharedTaskMultitask: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForSharedTaskMultitask from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSharedTaskMultitask were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier_first.weight', 'classifier_first.bias', 'classifier_second.weight', 'classifier_second.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ======== Epoch 1 / 30 ========
# Training...
#
#   Average training loss: 1.434337
# Training...
#
#   Average training loss: 0.023724
#
# Running Validation...
#   Metric: 0.342933
#   Validation Loss: 0.132457
#
# ======== Epoch 2 / 30 ========
# Training...
#
#   Average training loss: 0.922968
# Training...
#
#   Average training loss: 0.019822
#
# Running Validation...
#   Metric: 0.276467
#   Validation Loss: 0.089308
#
# ======== Epoch 3 / 30 ========
# Training...
#
#   Average training loss: 0.829741
# Training...
#
#   Average training loss: 0.020358
#
# Running Validation...
#   Metric: 0.294273
#   Validation Loss: 0.099569
#
# ======== Epoch 4 / 30 ========
# Training...
#
#   Average training loss: 0.776849
# Training...
#
#   Average training loss: 0.018866
#
# Running Validation...
#   Metric: 0.259321
#   Validation Loss: 0.078487
#
# ======== Epoch 5 / 30 ========
# Training...
#
#   Average training loss: 0.747161
# Training...
#
#   Average training loss: 0.019318
#
# Running Validation...
#   Metric: 0.291489
#   Validation Loss: 0.096496
#
# ======== Epoch 6 / 30 ========
# Training...
#
#   Average training loss: 0.718367
# Training...
#
#   Average training loss: 0.015245
#
# Running Validation...
#   Metric: 0.270919
#   Validation Loss: 0.083356
#
# ======== Epoch 7 / 30 ========
# Training...
#
#   Average training loss: 0.700252
# Training...
#
#   Average training loss: 0.013700
#
# Running Validation...
#   Metric: 0.227378
#   Validation Loss: 0.061058
#
# ======== Epoch 8 / 30 ========
# Training...
#
#   Average training loss: 0.679104
# Training...
#
#   Average training loss: 0.012685
#
# Running Validation...
#   Metric: 0.259326
#   Validation Loss: 0.076753
#
# ======== Epoch 9 / 30 ========
# Training...
#
#   Average training loss: 0.660181
# Training...
#
#   Average training loss: 0.012003
#
# Running Validation...
#   Metric: 0.269664
#   Validation Loss: 0.082013
#
# ======== Epoch 10 / 30 ========
# Training...
#
#   Average training loss: 0.642982
# Training...
#
#   Average training loss: 0.013210
#
# Running Validation...
#   Metric: 0.227375
#   Validation Loss: 0.060441
#
# ======== Epoch 11 / 30 ========
# Training...
#
#   Average training loss: 0.623378
# Training...
#
#   Average training loss: 0.010937
#
# Running Validation...
#   Metric: 0.237613
#   Validation Loss: 0.065100
#
# ======== Epoch 12 / 30 ========
# Training...
#
#   Average training loss: 0.608204
# Training...
#
#   Average training loss: 0.011193
#
# Running Validation...
#   Metric: 0.232218
#   Validation Loss: 0.062456
#
# ======== Epoch 13 / 30 ========
# Training...
#
#   Average training loss: 0.590458
# Training...
#
#   Average training loss: 0.012471
#
# Running Validation...
#   Metric: 0.200566
#   Validation Loss: 0.048054
#
# ======== Epoch 14 / 30 ========
# Training...
#
#   Average training loss: 0.567177
# Training...
#
#   Average training loss: 0.009214
#
# Running Validation...
#   Metric: 0.209921
#   Validation Loss: 0.052184
#
# ======== Epoch 15 / 30 ========
# Training...
#
#   Average training loss: 0.549368
# Training...
#
#   Average training loss: 0.009775
#
# Running Validation...
#   Metric: 0.198543
#   Validation Loss: 0.047373
#
# ======== Epoch 16 / 30 ========
# Training...
#
#   Average training loss: 0.532379
# Training...
#
#   Average training loss: 0.009758
#
# Running Validation...
#   Metric: 0.201556
#   Validation Loss: 0.048520
#
# ======== Epoch 17 / 30 ========
# Training...
#
#   Average training loss: 0.518556
# Training...
#
#   Average training loss: 0.009338
#
# Running Validation...
#   Metric: 0.181391
#   Validation Loss: 0.040328
#
# ======== Epoch 18 / 30 ========
# Training...
#
#   Average training loss: 0.501368
# Training...
#
#   Average training loss: 0.007161
#
# Running Validation...
#   Metric: 0.166777
#   Validation Loss: 0.035013
#
# ======== Epoch 19 / 30 ========
# Training...
#
#   Average training loss: 0.490279
# Training...
#
#   Average training loss: 0.006528
#
# Running Validation...
#   Metric: 0.152637
#   Validation Loss: 0.030321
#
# ======== Epoch 20 / 30 ========
# Training...
#
#   Average training loss: 0.474349
# Training...
#
#   Average training loss: 0.006388
#
# Running Validation...
#   Metric: 0.141993
#   Validation Loss: 0.026631
#
# ======== Epoch 21 / 30 ========
# Training...
#
#   Average training loss: 0.462462
# Training...
#
#   Average training loss: 0.006751
#
# Running Validation...
#   Metric: 0.132103
#   Validation Loss: 0.023489
#
# ======== Epoch 22 / 30 ========
# Training...
#
#   Average training loss: 0.451623
# Training...

# %%
print(8)

# %%
for window_ix in results_window:
    results_window[window_ix]['mae'] = results_window[window_ix].apply(lambda x: mean_absolute_error([x.preds],[x.true_val]), axis=1)
    results_window[window_ix]['mse'] = results_window[window_ix].apply(lambda x: mean_squared_error([x.preds],[x.true_val]), axis=1)
    results_window[window_ix]['discrete_occur'] = results_window[window_ix].apply(lambda x: x.occur_target if (x.occur_target == 0 or x.occur_target == 1) else 2, axis=1)

# %%
print(8)
# Out:
# 8

# %%
for window_ix in results_window:
    print('Window of', window_ix)

    mae = results_window[window_ix].groupby(['index']).mae.mean()
    mse = results_window[window_ix].groupby(['index']).mse.mean()
    #r_2 = results_window[window_ix].groupby(['index']).
    
    print('MAE --- Mean:', round(np.mean(mae), 4), ' Std:', round(np.std(mae), 4))
    print('MSE --- Mean:', round(np.mean(mse), 4), ' Std:', round(np.std(mse), 4))
    #print('R2  --- Mean:', round(np.mean(r_2), 4), ' Std:', round(np.std(r_2), 4))
    print()
# Out:
# Window of 0
# MAE --- Mean: 0.0712  Std: 0.0028
# MSE --- Mean: 0.0083  Std: 0.0007
#
# Window of 1
# MAE --- Mean: 0.0742  Std: 0.0033
# MSE --- Mean: 0.0092  Std: 0.0009
#
# Window of 2
# MAE --- Mean: 0.0771  Std: 0.0029
# MSE --- Mean: 0.0102  Std: 0.0008

# %%
for window_ix in results_window:
    df_temp = results_window[window_ix].groupby(['index', 'discrete_occur']).agg({'mse': 'mean',
                                                                         'mae': 'mean'}).reset_index()
    df_temp = df_temp.groupby('discrete_occur').agg({'mse': ['mean', 'std'],
                                          'mae': ['mean', 'std']}).reset_index()
    df_temp.columns = ['_'.join(col).strip('_') for col in df_temp.columns]
    print('Window of', window_ix)
    print(df_temp)
    print()
# Out:
# Window of 0
#    discrete_occur  mse_mean   mse_std  mae_mean   mae_std
# 0               0  0.009071  0.000851  0.072996  0.003400
# 1               1  0.009685  0.001270  0.076128  0.004915
# 2               2  0.007628  0.001031  0.069021  0.004490
#
# Window of 1
#    discrete_occur  mse_mean   mse_std  mae_mean   mae_std
# 0               0  0.010002  0.001435  0.076563  0.004284
# 1               1  0.009550  0.001204  0.074770  0.004041
# 2               2  0.008778  0.001300  0.072886  0.005334
#
# Window of 2
#    discrete_occur  mse_mean   mse_std  mae_mean   mae_std
# 0               0  0.011495  0.001898  0.081859  0.005849
# 1               1  0.010277  0.001694  0.077377  0.005610
# 2               2  0.009527  0.000914  0.074760  0.003826

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
def find_pos(sentence, ref):
    try:
        doc = nlp(sentence)
        for token in doc:
            if token.text == ref:
                return token.pos_
        return np.nan            
    except:
        return np.nan

# %%
for window_ix in results_window:
    print(window_ix)
    results_window[window_ix]['pos_label'] =  results_window[window_ix].apply(lambda x: find_pos(x.raw, x.target), axis=1)
# Out:
# 0
# 1
# 2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

for window_ix in results_window:
    print('Window size of:', window_ix)
    sns.lineplot(x='pos_label', y='mae', data=results_window[window_ix].loc[results_window[window_ix].pos_label.notnull()], ci=98, markers='o')
    plt.show()
# Out:
# Window size of: 0
# Window size of: 1
# Window size of: 2

# %%
for window_ix in results_window:
    print('Window size of:', window_ix)
    results_many = results_window[window_ix].loc[results_window[window_ix].discrete_occur > 1].reset_index(drop=True)
    results_one = results_window[window_ix].loc[results_window[window_ix].discrete_occur == 1].reset_index(drop=True)
    results_zero = results_window[window_ix].loc[results_window[window_ix].discrete_occur == 0].reset_index(drop=True)
    
    p1 = sns.lineplot(x='pos_label', y='mae', data=results_many.loc[results_many.pos_label.notnull()], ci=98, markers='o', color='blue')
    p2 = sns.lineplot(x='pos_label', y='mae', data=results_one.loc[results_one.pos_label.notnull()], ci=98, markers='o', color='black')
    p3 = sns.lineplot(x='pos_label', y='mae', data=results_zero.loc[results_zero.pos_label.notnull()], ci=98, markers='o', color='green')
    plt.legend(['mas de uno', 'uno', 'cero'])
    plt.show()
# Out:
# Window size of: 0
# Window size of: 1
# Window size of: 2
